# %% [markdown]
# # Variational Autoencoder with PyTorch

# %%
pip install torch torchvision
# Out:
# Requirement already satisfied: torch in c:\users\bouka\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.5.1)
# Requirement already satisfied: torchvision in c:\users\bouka\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.20.1)
# Requirement already satisfied: filelock in c:\users\bouka\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\bouka\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in c:\users\bouka\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\bouka\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\bouka\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch) (2024.6.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\bouka\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\bouka\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\bouka\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torchvision) (1.26.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\bouka\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bouka\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2->torch) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\BOUKA\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Imports

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import os
for dirname, _, filenames in os.walk('/inputs'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import nn, optim
from torch.autograd import Variable
from sklearn.decomposition import PCA

import pandas as pd
import numpy as np
from sklearn import preprocessing

# Any results you write to the current directory are saved as output.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Get a quick view of the data

# %%
DATA_PATH = r'C:\Users\BOUKA\Downloads\VAE-Code\inputs\heart_cleveland_upload.csv'
df = pd.read_csv(DATA_PATH, sep=',')
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'condition'],
#       dtype='object')

# %% [markdown]
# ## Process datasets

# %% [markdown]
# ### Heart Cleveland dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        297 non-null    int64
#  1   sex        297 non-null    int64
#  2   cp         297 non-null    int64
#  3   trestbps   297 non-null    int64
#  4   chol       297 non-null    int64
#  5   fbs        297 non-null    int64
#  6   restecg    297 non-null    int64
#  7   thalach    297 non-null    int64
#  8   exang      297 non-null    int64
#  9   oldpeak    297 non-null    float64
#  10  slope      297 non-null    int64
#  11  ca         297 non-null    int64
#  12  thal       297 non-null    int64
#  13  condition  297 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 32.6 KB

# %%
df['condition'].value_counts()
# Out:
# condition
# 0    160
# 1    137
# Name: count, dtype: int64

# %% [markdown]
# #### Null Values

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalach      0
# exang        0
# oldpeak      0
# slope        0
# ca           0
# thal         0
# condition    0
# dtype: int64

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean    54.542088    0.676768    2.158249  131.693603  247.350168    0.144781
# std      9.049736    0.468500    0.964859   17.762806   51.997583    0.352474
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    2.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    2.000000  130.000000  243.000000    0.000000
# 75%     61.000000    1.000000    3.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.996633  149.599327    0.326599    1.055556    0.602694    0.676768
# std      0.994914   22.941562    0.469761    1.166123    0.618187    0.938965
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.600000    1.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    3.000000
#
#              thal   condition
# count  297.000000  297.000000
# mean     0.835017    0.461279
# std      0.956690    0.499340
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      2.000000    1.000000
# max      2.000000    1.000000

# %% [markdown]
# #### Cleansing the data: removing outliers

# %%
for col in df.columns:
    print(f" {col}  unique val {df[col].unique()} and  counts: {df[col].value_counts()}")
# Out:
#  age  unique val [69 66 65 64 63 61 60 59 58 56 52 51 45 42 40 38 34 74 71 70 62 57 55 54
#  50 49 48 46 44 41 35 29 76 68 67 53 47 43 39 37 77] and  counts: age
# 58    18
# 57    17
# 54    16
# 59    14
# 60    12
# 51    12
# 56    11
# 52    11
# 44    11
# 62    11
# 64    10
# 41    10
# 63     9
# 67     9
# 61     8
# 55     8
# 45     8
# 42     8
# 65     8
# 46     7
# 48     7
# 50     7
# 43     7
# 66     7
# 53     7
# 49     5
# 47     5
# 70     4
# 68     4
# 39     4
# 35     4
# 69     3
# 71     3
# 40     3
# 34     2
# 37     2
# 76     1
# 29     1
# 74     1
# 38     1
# 77     1
# Name: count, dtype: int64
#  sex  unique val [1 0] and  counts: sex
# 1    201
# 0     96
# Name: count, dtype: int64
#  cp  unique val [0 1 2 3] and  counts: cp
# 3    142
# 2     83
# 1     49
# 0     23
# Name: count, dtype: int64
#  trestbps  unique val [160 140 150 138 110 170 145 134 178 120 118 152 125 148 156 128 136 130
#  124 154 135 132 108 192 101 105 112 126 122 180 115 146 155 102 172 100
#   94 129 142 144 106 117 158 174 164 114 165 200 123 104] and  counts: trestbps
# 120    37
# 130    36
# 140    32
# 110    19
# 150    17
# 160    11
# 128    10
# 125    10
# 138    10
# 112     9
# 118     7
# 132     7
# 108     6
# 124     6
# 135     6
# 152     5
# 145     5
# 134     5
# 100     4
# 170     4
# 122     4
# 126     3
# 142     3
# 115     3
# 180     3
# 105     3
# 136     3
# 178     2
# 146     2
# 102     2
# 148     2
# 94      2
# 144     2
# 117     1
# 123     1
# 200     1
# 165     1
# 114     1
# 164     1
# 174     1
# 158     1
# 101     1
# 106     1
# 192     1
# 129     1
# 172     1
# 155     1
# 156     1
# 154     1
# 104     1
# Name: count, dtype: int64
#  chol  unique val [234 239 226 282 211 227 233 240 270 288 273 204 283 193 186 298 213 264
#  244 199 231 182 269 302 245 246 195 281 208 221 284 319 236 261 232 294
#  250 262 342 309 325 201 205 271 266 229 197 160 308 263 219 220 295 203
#  198 235 306 157 192 210 265 254 274 277 564 212 278 417 360 335 313 252
#  243 185 318 178 218 230 224 340 168 126 256 258 214 304 267 196 222 175
#  188 149 275 255 257 253 177 141 242 315 209 180 268 321 215 174 322 286
#  299 237 223 228 225 248 303 407 330 187 164 394 260 307 166 207 206 293
#  305 326 249 176 216 259 300 276 289 241 131 354 184 409 217 353 327 200
#  311 169 290 341 247 172 167 183] and  counts: chol
# 234    6
# 197    6
# 212    5
# 269    5
# 204    5
#       ..
# 322    1
# 237    1
# 281    1
# 195    1
# 183    1
# Name: count, Length: 152, dtype: int64
#  fbs  unique val [1 0] and  counts: fbs
# 0    254
# 1     43
# Name: count, dtype: int64
#  restecg  unique val [2 0 1] and  counts: restecg
# 0    147
# 2    146
# 1      4
# Name: count, dtype: int64
#  thalach  unique val [131 151 114 174 144 155 150 145 171 159 125 162 190 178 132 182 121 143
#  120 179 103 140 164 160 152 141 169 153 163 161 166 156 195 172 158 184
#  168 180 175 138 170 173 188 192 202 116 130 112 146 115 157 148 133  97
#  137  96 134 165 154 142 147 167 123 149 139 126 194 187 109 108 129  71
#  127 122 105 136  99 106  90 111 124  88 117 113  95 186 128 118 185 177
#  181] and  counts: thalach
# 162    11
# 163     9
# 160     9
# 152     8
# 172     7
#        ..
# 192     1
# 202     1
# 167     1
# 97      1
# 195     1
# Name: count, Length: 91, dtype: int64
#  exang  unique val [0 1] and  counts: exang
# 0    200
# 1     97
# Name: count, dtype: int64
#  oldpeak  unique val [0.1 1.8 2.6 1.4 0.6 2.3 0.9 4.2 0.2 0.  0.8 1.  1.9 1.2 3.8 0.4 0.3 1.3
#  1.1 0.7 2.9 2.  1.6 1.5 3.  2.2 2.5 3.2 0.5 2.4 3.6 3.5 3.4 2.8 4.  6.2
#  4.4 2.1 5.6 3.1] and  counts: oldpeak
# 0.0    96
# 1.2    17
# 0.6    14
# 1.4    13
# 0.8    13
# 1.0    13
# 0.2    12
# 1.6    11
# 1.8    10
# 2.0     9
# 0.4     8
# 0.1     6
# 2.8     6
# 2.6     6
# 1.9     5
# 0.5     5
# 3.0     5
# 1.5     5
# 2.2     4
# 3.6     4
# 0.9     3
# 4.0     3
# 0.3     3
# 2.4     3
# 3.4     3
# 1.1     2
# 2.3     2
# 2.5     2
# 3.2     2
# 4.2     2
# 4.4     1
# 5.6     1
# 6.2     1
# 2.1     1
# 2.9     1
# 3.5     1
# 0.7     1
# 1.3     1
# 3.8     1
# 3.1     1
# Name: count, dtype: int64
#  slope  unique val [1 0 2] and  counts: slope
# 0    139
# 1    137
# 2     21
# Name: count, dtype: int64
#  ca  unique val [1 2 0 3] and  counts: ca
# 0    174
# 1     65
# 2     38
# 3     20
# Name: count, dtype: int64
#  thal  unique val [0 2 1] and  counts: thal
# 0    164
# 2    115
# 1     18
# Name: count, dtype: int64
#  condition  unique val [0 1] and  counts: condition
# 0    160
# 1    137
# Name: count, dtype: int64

# %% [markdown]
# * **There are two classes: 0 is 'Non Diseased' and 1 is 'Diseased'**

# %% [markdown]
# ### Visualizations

# %%
sns.pairplot(data=df, hue='condition')

# %% [markdown]
# #### Spearman Rank Correlation

# %%
corr = df.corr(method="spearman")
sns.heatmap(corr,annot=False)
# Out:
# <Axes: >

# %% [markdown]
# * We drop outlier values using **IQR(Interquartile Range Method)**

# %%
df.rename(columns={'condition':"Outcome"}, inplace=True)

# %%
cols = [col for col in df.columns if col!="Outcome"]
cont_cols = ["age", 'trestbps', "chol", "thalach"]
for col in cont_cols:
        plt.figure(figsize=(8, 6))
        sns.boxplot(data=df, x="Outcome", y=col)
        plt.title(f'Boxplot of {col} by Outcome')
        plt.show()

# %%
def removeOutlier(col):
    sorted(col)
    quant1, quant2 = col.quantile([0.25, 0.75])
    IQR = quant2 - quant1
    lowerRange = quant1 - (1.5 * IQR)
    upperRange = quant2 + (1.5 * IQR)
    return lowerRange, upperRange

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean    54.542088    0.676768    2.158249  131.693603  247.350168    0.144781
# std      9.049736    0.468500    0.964859   17.762806   51.997583    0.352474
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    2.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    2.000000  130.000000  243.000000    0.000000
# 75%     61.000000    1.000000    3.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.996633  149.599327    0.326599    1.055556    0.602694    0.676768
# std      0.994914   22.941562    0.469761    1.166123    0.618187    0.938965
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.600000    1.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    3.000000
#
#              thal     Outcome
# count  297.000000  297.000000
# mean     0.835017    0.461279
# std      0.956690    0.499340
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      2.000000    1.000000
# max      2.000000    1.000000

# %%
cont_cols = ["age", 'trestbps', "chol", "thalach"]

# %%
for col in cont_cols:
    lowScore, highScore = removeOutlier(df[col])
    print(f"Column: {col}, Lower Bound: {lowScore}, Upper Bound: {highScore}")
    df[col] = np.where(df[col]>highScore, highScore, df[col])
    df[col] = np.where(df[col]<lowScore, lowScore, df[col])
# Out:
# Column: age, Lower Bound: 28.5, Upper Bound: 80.5
# Column: trestbps, Lower Bound: 90.0, Upper Bound: 170.0
# Column: chol, Lower Bound: 113.5, Upper Bound: 373.5
# Column: thalach, Lower Bound: 83.5, Upper Bound: 215.5

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean    54.542088    0.676768    2.158249  131.343434  246.260943    0.144781
# std      9.049736    0.468500    0.964859   16.801401   47.836752    0.352474
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    2.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    2.000000  130.000000  243.000000    0.000000
# 75%     61.000000    1.000000    3.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    3.000000  170.000000  373.500000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.996633  149.641414    0.326599    1.055556    0.602694    0.676768
# std      0.994914   22.807957    0.469761    1.166123    0.618187    0.938965
# min      0.000000   83.500000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.600000    1.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    3.000000
#
#              thal     Outcome
# count  297.000000  297.000000
# mean     0.835017    0.461279
# std      0.956690    0.499340
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      2.000000    1.000000
# max      2.000000    1.000000

# %% [markdown]
# * **Check if the outliers are handled**

# %%
cols = [col for col in df.columns if col!="Outcome"]
for col in cont_cols:
        plt.figure(figsize=(8, 6))
        sns.boxplot(data=df, x="Outcome", y=col)
        plt.title(f'Boxplot of {col} by Outcome')
        plt.show()

# %% [markdown]
# ### save the preprocessed dataset "HeartCleveland_processed.csv"

# %%
df.head()
# Out:
#     age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  69.0    1   0     160.0  234.0    1        2    131.0      0      0.1
# 1  69.0    0   0     140.0  239.0    0        0    151.0      0      1.8
# 2  66.0    0   0     150.0  226.0    0        0    114.0      0      2.6
# 3  65.0    1   0     138.0  282.0    1        2    174.0      0      1.4
# 4  64.0    1   0     110.0  211.0    0        2    144.0      1      1.8
#
#    slope  ca  thal  Outcome
# 0      1   1     0        0
# 1      0   2     0        0
# 2      2   0     0        0
# 3      1   1     0        1
# 4      1   0     0        0

# %%
df.to_csv(path_or_buf="HeartCleveland_processed.csv")
